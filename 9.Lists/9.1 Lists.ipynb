# %% [markdown]
# ![image.png](attachment:e80ac019-1871-46ea-a992-4247b701cc2a.png)

# %% [markdown]
# ![image.png](attachment:64f9bb31-8e9f-4918-9f76-712168a959ea.png)

# %% [markdown]
# ![image.png](attachment:6e517252-4f6e-44a4-94fa-fa5bf24d5bf0.png)

# %%
#using list constructor
my_list=list((1,2,3))
print(my_list)
# Out:
# [1, 2, 3]

# %%
#using square brackets
my_list2=[1,2,3]
print(my_list2)
# Out:
# [1, 2, 3]

# %%
#with heterogeneous items
a=[1,True,3.5,10+4j,'sai',[1,2,3]]
print(a)
# Out:
# [1, True, 3.5, (10+4j), 'sai', [1, 2, 3]]

# %%
#empty list
b=[]
print(b,type(b))
c=list()
print(c,type(c))
# Out:
# [] <class 'list'>
# [] <class 'list'>

# %%
my_list=[1,2,3]
print(len(my_list))
# Out:
# 3

# %%
max(my_list)
# Out:
# 3

# %%
min(my_list)
# Out:
# 1

# %%
a=[1,3,52,4,1]
sorted(a)
# Out:
# [1, 1, 3, 4, 52]

# %%
a
# Out:
# [1, 3, 52, 4, 1]

# %% [markdown]
# ![image.png](attachment:d043e1f4-64e0-4037-ae77-f1289619e4a4.png)`

# %% [markdown]
# ##### Note:
#
# **As Lists are ordered sequences of items, the index values start from 0 to the Lists length.**
# **Whenever we try to access an item with an index more than the Lists length, it will throw the 'Index Error'.**
# **Similarly, the index values are always an integer. If we give any other type, then it will throw Type Error.**

# %%
my_list = [10, 20, 'Jessa', 12.50, 'Emma']
my_list[1]
my_list[4]
# Out:
# 'Emma'

# %%
my_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 my_list[5]
#
# IndexError: list index out of range

# %%
my_list[a]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 my_list[a]
#
# TypeError: list indices must be integers or slices, not list

# %%
#Negative indexing
my_list[-1]
# Out:
# 'Emma'

# %%
my_list[-4]
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:f299e7fc-28be-4bc8-ac05-a0c59d23d11d.png)

# %%
my_list[::]
# Out:
# [10, 20, 'Jessa', 12.5, 'Emma']

# %%
my_list[1:]
# Out:
# [20, 'Jessa', 12.5, 'Emma']

# %%
my_list
# Out:
# [10, 20, 'Jessa', 12.5, 'Emma']

# %%
my_list[::-1]
# Out:
# ['Emma', 12.5, 'Jessa', 20, 10]

# %%
my_list[1::2]
# Out:
# [20, 12.5]

# %%
my_list[2:5]
# Out:
# ['Jessa', 12.5, 'Emma']

# %%
#iterating a list
my_list = [5, 8, 'Tom', 7.50, 'Emma']
for item in my_list:
    print(item)
# Out:
# 5
# 8
# Tom
# 7.5
# Emma

# %%
for i in range(0,len(my_list)):
    print(my_list[i])
# Out:
# 5
# 8
# Tom
# 7.5
# Emma

# %% [markdown]
# ![image.png](attachment:1a51c316-6ae1-40b7-a464-03a0d1889222.png)

# %%
a=[1,2,3]
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a.append(['sai',True,10.5])
a
# Out:
# [1, 2, 3, 4, ['sai', True, 10.5]]

# %%
a
# Out:
# [1, 2, 3, 4, ['sai', True, 10.5]]

# %%
a.insert(2,25)
a
# Out:
# [1, 2, 25, 3, 4, ['sai', True, 10.5]]

# %%
a.insert(3,[1,2,3])
a
# Out:
# [1, 2, 25, [1, 2, 3], [1, 2, 3], 3, 4, ['sai', True, 10.5]]

# %%
my_list = list([5, 8, 'Tom', 7.50])
my_list.extend([1,2,34,5,True])

# %%
my_list
# Out:
# [5, 8, 'Tom', 7.5, 1, 2, 34, 5, True]

# %%
#modifying a item in the list.
my_list = list([2, 4, 6, 8, 10, 12])
my_list[0]=10
print(my_list)
# Out:
# [10, 4, 6, 8, 10, 12]

# %%
my_list[1:4]=[20,30,40]
print(my_list)
# Out:
# [10, 20, 30, 40, 10, 12]

# %%
my_list[3:]=[50,60,70]
print(my_list)
# Out:
# [10, 20, 30, 50, 60, 70]

# %%
my_list = list([2, 4, 6, 8])
square=[]
for i in range(0,len(my_list)):
    square.append(my_list[i]**2)
print(square)
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# ![image.png](attachment:9ad2490a-9741-4a35-b6a2-ebdaffe3de09.png)

# %%
a=[10,20,20,30,40,'sai','sai']
print(a)
# Out:
# [10, 20, 20, 30, 40, 'sai', 'sai']

# %%
a.clear()
print(a)
# Out:
# []

# %%
a=[10,20,20,30,40,'sai','sai']
print(a)
a.remove(20)
print(a)
# Out:
# [10, 20, 20, 30, 40, 'sai', 'sai']
# [10, 20, 30, 40, 'sai', 'sai']

# %%
a=[10,20,20,30,40,'sai','sai']
print(a)
a.remove('sai')
print(a)
# Out:
# [10, 20, 20, 30, 40, 'sai', 'sai']
# [10, 20, 20, 30, 40, 'sai']

# %%
my_list = list([6, 4, 6, 6, 8, 12])
for item in my_list:
    my_list.remove(6)
print(my_list)
# Out:
# [4, 8, 12]

# %%
my_list = list([2, 4, 6, 8, 10, 12])
print(my_list.pop(2))
print(my_list)
# Out:
# 6
# [2, 4, 8, 10, 12]

# %%
my_list = list([2, 4, 6, 8, 10, 12])
print(my_list.pop())
print(my_list)
# Out:
# 12
# [2, 4, 6, 8, 10]

# %%
#Use del keyword along with list slicing to remove the range of items
my_list = list([2, 4, 6, 8, 10, 12])
del my_list
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       2 my_list = list([2, 4, 6, 8, 10, 12])
#       3 del my_list
# ----> 4 print(my_list)
#
# NameError: name 'my_list' is not defined

# %%
my_list = list([2, 4, 6, 8, 10, 12])
del my_list[2:5]
print(my_list)
# Out:
# [2, 4, 12]

# %% [markdown]
# ### Finding an index for an element in the list

# %% [markdown]
# - The index() function will accept the value of the element as a parameter and returns the first occurrence of the element
# - or returns ValueError if the element does not exist.

# %%
my_list = list([2, 4, 6, 8, 10, 12])
print(my_list.index(8))
print(my_list.index(11))
# Out:
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 3
#       1 my_list = list([2, 4, 6, 8, 10, 12])
#       2 print(my_list.index(8))
# ----> 3 print(my_list.index(11))
#
# ValueError: 11 is not in list

# %%
my_list1 = [1, 2, 3]
my_list2 = [4, 5, 6]
a=my_list1+my_list2
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Copying a list
# Using assignment operator (=)
# - This is a straightforward way of creating a copy.
# - In this method, the new list will be a deep copy.
# - The changes that we make in the original list will be reflected in the new list.
#
# This is called deep copying.
# As seen in the above example a copy of the list has been created. The changes made to the original list are reflected in the copied list as well.
#
# Note: When you set list1 = list2, you are making them refer to the same list object, so when you modify one of them, all references associated with that object reflect the current state of the object. So don’t use the assignment operator to copy the dictionary instead use the copy() method.

# %%
my_list1 = [1, 2, 3]
copy_list=my_list1
print(copy_list)
copy_list[0]='sai'
print(my_list1)
# Out:
# [1, 2, 3]
# ['sai', 2, 3]

# %% [markdown]
# ### Using the copy() method
# The copy method can be used to create a copy of a list. This will create a new list and any changes made in the original list will not reflect in the new list. This is shallow copying.

# %%
my_list1 = [1, 2, 3]
new_list=my_list1.copy()
print(id(my_list1),my_list1)
print(id(new_list),new_list)
# Out:
# 1607598439296 [1, 2, 3]
# 1607598427584 [1, 2, 3]

# %%
new_list[0]='sai'
print(id(my_list1),my_list1)
print(id(new_list),new_list)
# Out:
# 1607598439296 [1, 2, 3]
# 1607598427584 ['sai', 2, 3]

# %%
mylist = [3, 4, 5, 6, 1]
mylist.reverse()
print(mylist)
# Out:
# [1, 6, 5, 4, 3]

# %%
mylist = [3, 4, 5, 6, 1]
print(sum(mylist))
print(max(mylist)) #returns the maximum number in the list.
print(min(mylist))
# Out:
# 19
# 6
# 1

# %% [markdown]
# ![image.png](attachment:f1a597d1-37cd-454e-a782-5b5ac20f8683.png)

# %%
samplelist1 = [1,1,True]
print(all(samplelist1))
# Out:
# True

# %%
samplelist2 = [0,1,True,1]
print(all(samplelist2))
# Out:
# False

# %%
samplelist3 = [0,0,False]
print("all() with all false values ::",all(samplelist3))

#empty list
samplelist4 = []
print(all(samplelist4))
# Out:
# all() with all false values :: False
# True

# %% [markdown]
# ![image.png](attachment:48d8d17f-db0a-40c4-82eb-cd2023bec826.png)

# %%
#with all true values
samplelist1 = [1,1,True]
print("any() True values::",any(samplelist1))

#with one false
samplelist2 = [0,1,True,1]
print("any() One false value ::",any(samplelist2))


#with all false
samplelist3 = [0,0,False]
print("any() all false values ::",any(samplelist3))

#empty list
samplelist4 = []
print("any() Empty list ::",any(samplelist4))
# Out:
# any() True values:: True
# any() One false value :: True
# any() all false values :: False
# any() Empty list :: False

# %%
nestedlist = [[2,4,6,8,10],[1,3,5,7,9]]
print("Accessing the third element from a second list in nestd list",nestedlist[1][2])
for i in nestedlist:
    print("The items in list are:",i)
    for j in i:
        print("The elements in the item are:",j)
# Out:
# Accessing the third element from a second list in nestd list 5
# The items in list are: [2, 4, 6, 8, 10]
# The elements in the item are: 2
# The elements in the item are: 4
# The elements in the item are: 6
# The elements in the item are: 8
# The elements in the item are: 10
# The items in list are: [1, 3, 5, 7, 9]
# The elements in the item are: 1
# The elements in the item are: 3
# The elements in the item are: 5
# The elements in the item are: 7
# The elements in the item are: 9

# %% [markdown]
# ![image.png](attachment:42cff6ba-75be-443e-b06b-9c88649ad943.png)

# %%
a=[1,2,3,4,5]
b=[i**2 for i in a if i>2]
b
# Out:
# [9, 16, 25]

# %%
c=[i for i in range(10) if i%2==0]

# %%
c
# Out:
# [0, 2, 4, 6, 8]
