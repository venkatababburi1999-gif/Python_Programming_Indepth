# %% [markdown]
# # Introduction to Python!
#
# > *“Any fool can write code that a computer can understand. Good programmers write code that humans can understand.”*
# > — Martin Fowler
#
# ---
# ## 📘 Topics to be Covered
#
# 1. **What is Python ?**
# 2. **Key Features of Python**
# 3. **Limitations of Python**
# 4. **Scope of Python**
# 5. **Python — A Programming or a Scripting Language?**
# 6. **Data types in Python**
# 7. **Programming Errors**
#
# ---

# %% [markdown]
# ## 1. What is Python?
#
# **Python** is a high-level, interpreted programming language known for its **simplicity**, **readability**, and **versatility**.
#
# - Created by **Guido van Rossum**
# - First released in **1991**
# - Now used by companies like **Google**, **Netflix**, **NASA**, **Tesla**, and **Meta**
#
# Python makes it **easy for beginners to start**, while still being **powerful enough** for experts to build complex systems.
#
# Python is one of the most popular programming language. why ?
#
# - Used in **cutting-edge fields**: AI, Machine Learning, Data Science, Automation, and more.
# - Beginner-friendly syntax.
# - Fast development and prototyping.
# - A huge collection of libraries for **everything**.
# - A massive, supportive community.
#
# ---
#
# ## 2. Key Features of Python
#
# - **Interpreted** – No compilation required; run code line-by-line.
# - **Dynamically Typed** – No need to declare variable types.
# - **High-Level Language** – Write code like you're writing English.
# - **Object-Oriented** – Build reusable and organized code.
# - **Cross-Platform** – Runs on Windows, Mac, Linux seamlessly.
#
# ---
# ## 3. Limitations of Python
#
# Even the best tools have limitations:
#
# - **Slower than C++/Java** because it is interpreted.
# - **Not ideal for mobile app development.**
# - **GIL (Global Interpreter Lock)**: Limits true multithreading.
# - **Runtime Errors** due to dynamic typing.
# - **High memory usage** compared to lower-level languages.
#
# ---
#
# ## 4. Scope of Python
#
# Python shines in:
#
# | Domain             | Tools/Libraries         | What You Can Build                             |
# |-------------------|-------------------------|------------------------------------------------|
# | Data Science       | `pandas`, `numpy`        | Analyze real-world data                        |
# | Machine Learning   | `scikit-learn`, `xgboost`| Predict house prices, recommend videos         |
# | AI / Deep Learning | `tensorflow`, `pytorch`  | Build chatbots, autonomous systems             |
# | Web Development    | `Flask`, `Django`        | Build websites and REST APIs                   |
# | Automation         | `selenium`, `pyautogui`  | Auto-fill forms, schedule emails               |
# | Games              | `pygame`                 | Build 2D games and interactive apps            |
#
# ---

# %% [markdown]
# ## 5. Python — A Programming or a Scripting Language?
#
# ---
# - Python is a general-purpose programming language that is often used as a scripting language.
# - Python as a scripting language - Used for quick automation or system-level tasks.
#   ```python
#
#     # Rename all .txt files in a folder
#     import os
#     folder = "C:/Users/Sanjeev/Desktop/textfiles"
#     for filename in os.listdir(folder):
#         if filename.endswith(".txt"):
#             new_name = filename.replace(" ", "_")
#             os.rename(os.path.join(folder, filename), os.path.join(folder, new_name))
#
#   ```
# - Python as a programming language - Used to build applications by organizing code using modules/classes/functions.
#     ```python
#
#     # Simple Student Management System
#     class Student:
#         def __init__(self, name, marks):
#             self.name = name
#             self.marks = marks
#
#         def get_grade(self):
#             if self.marks >= 90:
#                 return "A"
#             elif self.marks >= 75:
#                 return "B"
#             else:
#                 return "C"
#
#     def main():
#         students = [
#             Student("Aman", 88),
#             Student("Rahul", 95)
#         ]
#
#         for s in students:
#             print(f"{s.name} got grade: {s.get_grade()}")
#
#     if __name__ == "__main__":
#         main()
#
#
#    ```
# - **Python is an object-oriented programming language like Java** – you can write class-based code, just like Java.
# - **Python is interpreted**, but **Java is compiled** – it runs via an interpreter rather than being compiled to machine code directly.
#
# Let’s understand this more clearly with an analogy:
#
# Analogy: Chef & Recipe
#
# | Concept                        |  **Python**                |   **Java**                       |
# |-------------------------------|-----------------------------|----------------------------------|
# | **Cooking Style (OOP)**        | Object-Oriented             | Object-Oriented                  |
# | **Cooking Method (Execution)** | Interpreted *(live cooking)* | Compiled *(pre-cooked and served)* |
#
# ---

# %% [markdown]
# ![image.png](attachment:68f16034-0fca-4e1a-9588-c7c8cd666a36.png)

# %% [markdown]
# ![image.png](attachment:63e130c9-b703-41c1-b188-ffeaa9f3feef.png)

# %% [markdown]
# ## Literals In Python
# > **Literals** in Python are fixed values written directly in the code that represent constant data. They provide a way to store numbers, text, or other essential information that does not change during program execution. Python supports different types of literals, such as numeric literals, string literals, Boolean literals, and special values like None. For example:
#
# - 10, 3.14, and 5 + 2j are numeric literals.
# - 'Hello' and "Python" are string literals.
# - True and False are Boolean literals.
# >Think of literals as the raw ingredients in your code. Python turns them into objects during execution.
# ---

# %% [markdown]
# ## 🔤 Common Python Literals
#
# | Literal Type     | Example Values               |
# |------------------|------------------------------|
# | Integer          | `0`, `42`, `-7`              |
# | Float            | `3.14`, `-0.001`, `2.0`      |
# | String           | `"hello"`, `'x'`, `""`       |
# | Boolean          | `True`, `False`              |
# | None             | `None`                       |
# | Complex          | `2 + 3j`, `-1j`              |
# | List             | `[1, 2, 3]`, `[]`            |
# | Tuple            | `(1, 2)`, `()`               |
# | Dictionary       | `{"a": 1}`, `{}`             |
# | Set              | `{1, 2, 3}`, `set()`         |

# %%
#object-strings
"saivardhan"
'saivardhan'
"Bsaivardhan@8110"
"$5.0"
"10"
"You're right!"
'Shakespeare once told "To be or not to be" in one of his plays'
""
''
" "
5
"""Hello
My name is
Boris.
"""

# %% [markdown]
# # Variables in Python
# In Python, variables are used to store data that can be referenced and manipulated during program execution. A variable is essentially a name that is assigned to a value.
#
# - Unlike Java and many other languages, Python variables do not require explicit declaration of type.
# - The type of the variable is inferred based on the value assigned
#
# Variables store data in a computer memory. Mnemonic variables are recommended to use in many programming languages. A mnemonic variable is a variable name that can be easily remembered and associated. A variable refers to a memory address in which data is stored
#
# # Rules for Naming Variables
# To use variables effectively, we must follow Python’s naming rules:
#
# - Variable names can only contain letters, digits and underscores (_).
# - A variable name cannot start with a digit.
# - Variable names are case-sensitive (myVar and myvar are different).
# - Avoid using Python keywords (e.g., if, else, for) as variable names.
# - Variable names are case-sensitive (firstname, Firstname, FirstName and FIRSTNAME) are different variables)
# ---

# %% [markdown]
# ## Reserved Words
# > In Python some words are reserved to represent some meaning or functionality. Such type of words are called Reserved words.
# ---

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Here are some of the list of valid variable names.
firstname
lastname
homecountry
my_first_name
_my_last_name
my_home_country
_if #if you want to use reserved word as a variable.
num1
num2
year2021
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Here are some of the list of valid variable names.
# ----> 2 firstname
#       3 lastname
#       4 homecountry
#
# NameError: name 'firstname' is not defined

# %% [markdown]
# We will use standard Python variable naming style which has been adopted by many Python developers. Python developers use snake case(snake_case) variable naming convention. We use underscore character after each word for a variable containing more than one word(eg. first_name, last_name, engine_rotation_speed). The example below is an example of standard naming of variables, underscore is required when the variable name is more than one word.
#
# When we assign a certain data type to a variable, it is called variable declaration. For instance in the example below my first name is assigned to a variable first_name. The equal sign is an assignment operator. Assigning means storing data in the variable. The equal sign in Python is not equality as in Mathematics.

# %%
first_name='Venkata Siva Sai Vardhan'
last_name='Babburi'
my_age=27
my_country="USA"
is_married=False
skills=['Python','SQL','Data Science','Machine Learning']

# %% [markdown]
# ## Built-In Functions
# In Python we have lots of built-in functions. Built-in functions are globally available for your use that mean you can make use of the built-in functions without importing or configuring. Some of the most commonly used Python built-in functions are the following: print(), len(), type(), int(), float(), str(), input(), list(), dict(), min(), max(), sum(), sorted(), open(), file(), help(), and dir(). In the following table you will see an exhaustive list of Python built-in functions taken from python documentation.
# ![image.png](attachment:fe210a1a-bdb6-4fa0-b039-6b2ed78cccaf.png)

# %%
print("Hello,World!") #Single arguments
print('Hello,World',True,5) #Multiple arguments
# Out:
# Hello,World!
# Hello,World True 5

# %%
#Printing the values stored in the variables.
print("My first name is:",first_name)
print('My last name is :',last_name)
print('My age is:',my_age)
# Out:
# My first name is: Venkata Siva Sai Vardhan
# My last name is : Babburi
# My age is: 27

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
dir(print)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']

# %%
#print function with multiple arguments and parameters
print("ABC","DEF","XYZ")
print("ABC","DEF","XYZ",sep='')
print("ABC","DEF","XYZ",sep=' ')
print("ABC","DEF","XYZ",sep='--')
print("ABC","DEF","XYZ",sep='--',end='\t')
print("ABC","DEF","XYZ",sep='--',end='**')
print("A", "B", "C", sep="**", end="#")
print("A", "B", "C", sep="**", end="###")
# Out:
# ABC DEF XYZ
# ABCDEFXYZ
# ABC DEF XYZ
# ABC--DEF--XYZ
# ABC--DEF--XYZ	ABC--DEF--XYZ**A**B**C#A**B**C###

# %%
#Important things to remember
print('sai')==print("sai")
"""We have to be a bit careful! The output we are seeing here is Python's string representation 
(any output to the terminal is a string - a bunch of characters) - not the actual internal value.
And Python tries to be "nice" by formatting the number in a more human readable fashion."""
# Out:
# sai
# sai
# 'We have to be a bit careful! The output we are seeing here is Python\'s string representation \n(any output to the terminal is a string - a bunch of characters) - not the actual internal value.\nAnd Python tries to be "nice" by formatting the number in a more human readable fashion.'

# %% [markdown]
# ![image.png](attachment:2ccddc5d-89b1-46fc-91b8-b94a57a5fc91.png)

# %%
print("Hello \"Python!\"")
print('Hello "Python!"')
print('Path: c:\\user\\bsaiv\\Desktop')
# Out:
# Hello "Python!"
# Hello "Python!"
# Path: c:\user\bsaiv\Desktop

# %%
print('Message1')

print('Message2')
# Out:
# Message1
# Message2

# %%
print('Message1')
print()
print('Message2')
# Out:
# Message1
#
# Message2

# %%
print('Message1\n')
print('Message2')
# Out:
# Message1
#
# Message2

# %%
print('Message1\n\n\n')
print('Message2')
# Out:
# Message1
#
#
#
# Message2

# %%
print('Message1\tMessage2')
# Out:
# Message1	Message2

# %%
print('Message1\bMessage2')
# Out:
# MessageMessage2

# %%
first_name,last_name,my_age='sai','babburi',25
print('first_name: ', first_name)
print('alst_name: ', first_name)
print('age: ',my_age)
# Out:
# first_name:  sai
# alst_name:  sai
# age:  25

# %% [markdown]
# ## Python input() Function
# - The input() function in Python is used to take input from the user. It waits for the user to type something on keyboard and once user presses Enter, it returns the value.
#
# - By default, input() always returns data as a string, even if you enter numbers. If you want other types like integer (int) or floating-point (float), you have to convert (typecast) the value explicitly

# %%
a=int(input('Enter a number into a:'))
b=input("Enter a string value into b:")
print(a,b)
# Out:
# Enter a number into a: 10
# Enter a string value into b: Venkata Siva Sai Vardhan Babburi
# 10 Venkata Siva Sai Vardhan Babburi

# %% [markdown]
# ## Comments in python
# Comment is not a python statement and thus is ignored by python interpreter. But, it is plain text that documents what the program is and how it is constructed.
#
# It is always good to write a comment that describes purpose of each statement included in a program.
#
# It increases readability of the program.
#
# In Python, one can write comments as:
# 1. Single line comment starting with a pound (#) sign
# 2. Paragraph comment that **STARTS** and **ENDS** with three consecutive single quotes (''') or three consecutive double quotes (""")

# %%
print("Good morning")
#print("Good afternoon")
print("Good night")
# This will perform a mathematical calculation
print(1 + 1) # Adds together 1 + 1
# print(1 + 1)
# print(1 + 1)
# print(1 + 1)
# Out:
# Good morning
# Good night
# 2

# %%
x=10 #single assignment
print(x)
x,y,z=10,20,30 #Multiple variables parallel assignemnt
print(x,y,z)
# Out:
# 10
# 10 20 30

# %%
#same value to multiple variables
a=b=c=10 #all will be pointing to the same object
print(a,b,c) 
#id() is one of Python’s simplest but most revealing built‑in functions. 
#It tells you the identity of an object — essentially where that object lives in memory.
print(id(a)) 
print(id(b))
print(id(c))
# Out:
# 10 10 10
# 140717971317960
# 140717971317960
# 140717971317960

# %%
#unpacking assignment
x,y,z=[1,True,'sai']
print(x)
print(y)
print(z)
# Out:
# 1
# True
# sai

# %%
#swapping values
a,b=1,2
print("Value of a is:",a)
print("Value of b is:",b)
a,b=b,a
print("Value of a after swapping is:",a)
print("Value of b after swapping is:",b)
# Out:
# Value of a is: 1
# Value of b is: 2
# Value of a after swapping is: 2
# Value of b after swapping is: 1

# %%
a,*b=[1,2,3,4]
print(a,b)
*a,b=[1,2,3,4]
print(a,b)
# Out:
# 1 [2, 3, 4]
# [1, 2, 3] 4

# %%
#del in Python is a statement, not a function. It removes a name (a variable, item, attribute, or slice) from the current namespace or container.
#It does not always delete the underlying object — it only deletes your reference to it.
#del removes a binding between a name and an object.
x=10
del(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 6
#       4 x=10
#       5 del(x)
# ----> 6 print(x)
#
# NameError: name 'x' is not defined

# %%
a = [1, 2, 3]
b = a
del a
print(b)
# Out:
# [1, 2, 3]

# %% [markdown]
# # 🧠 LIFO, Stack, and Heap in Python
#
# ## 🔷 What is LIFO?
# **LIFO = Last In, First Out**
#
# It describes how a stack works:
# The last item added is the first one removed.
#
# Example analogy: a stack of plates.
#
# ---
#
# ## 🔷 What is a Stack?
# A **stack** is a memory structure that follows LIFO.
#
# In Python, the **call stack** stores:
#
# - Function call frames
# - Local variable *names*
# - Return addresses
# - References to objects in the heap
#
# Important:
# Python does **not** store actual objects on the stack — only **references**.
#
# ---
#
# ## 🔷 What is the Heap?
# The **heap** is a large memory area where Python stores **all actual objects**, such as:
#
# - integers
# - strings
# - lists
# - dictionaries
# - functions
# - classes
#
# Every object you create in Python lives in the heap.
#
# ---
#
# ## 🔷 How Python Uses Stack + Heap Together
#
# ### Example
# ```python
# def func():
#     x = [1, 2, 3]
# func frame:
#     x → reference to a list object
# list object: [1, 2, 3]
# When the function ends:
# - The stack frame is removed (LIFO)
# - The heap object stays if something else references it
# - Otherwise, Python’s garbage collector removes it later

# %% [markdown]
# ## 6. Data types in Python
# In Python, datatypes define what kind of value a variable can hold. Python is dynamically typed, so you don’t have to declare types explicitly—they're inferred at runtime.
# ![image.png](attachment:e0b26f04-7837-4263-8ae5-d57849980886.png)
# Fundamental (or primitive) data types are the basic building blocks of data in Python. They are simple, core types from which more complex structures can be made.
#
# Integer, float, boolean, None, and string are **primitive data types** because they represent a single value.
#
# Other data types like list, tuple, set, frozenset and dictionary are often called **data structures or containers** because they hold multiple pieces of data together.
#
# A literal is a value. A variable is a name pointing to that value.
#
# A variable in Python is defined through assignment. There is no concept of declaring a variable outside of that assignment.
#
# There are several data types in Python. To identify the data type we use the type built-in function. I would like to ask you to focus on understanding different data types very well. When it comes to programming, it is all about data types.
# ![image.png](attachment:6606a8ea-de16-435a-832e-894c57f5fa8c.png)
#
# ![image.png](attachment:eebf9a0b-d292-492b-a55c-40c25b7eb806.png)

# %% [markdown]
# # Numbers
# Number data types in Python:
#
# Integers: Integer(negative, zero and positive) numbers Example: ... -3, -2, -1, 0, 1, 2, 3 ...
#
# Floating Point Numbers(Decimal numbers) Example: ... -3.5, -2.25, -1.0, 0.0, 1.1, 2.2, 3.5 ...
#
# Complex Numbers Example: 1 + j, 2 + 4j, 1 - 1j

# %% [markdown]
# ## Integers
# Integer literals are created by any number without a decimal or complex component.

# %%
a=10
print(id(a))
print(type(a))
# Out:
# 140717971317960
# <class 'int'>

# %% [markdown]
# # 🐍 Understanding `type()` in Python
#
# ## 📌 What is `type()`?
# `type()` is a built‑in Python function that tells you **the data type of a value, variable, or object**.
#
# It’s one of the simplest yet most important tools for debugging, learning, and understanding how Python behaves.
#
# ---
#
# ## 🧠 Basic Syntax
#
# ```python
# type(object)

# %%
print(type(10))
print(type(10.5))
print(type(10.5+10j))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
type("hello")     # str
# Out:
# str

# %%
type(True) #boolean
# Out:
# bool

# %%
type([1,2,3,4])
# Out:
# list

# %%
type((1,2,3))
# Out:
# tuple

# %%
type({1,2,3})
# Out:
# set

# %%
type({'a':1})
# Out:
# dict

# %% [markdown]
# ### We can represent int value in 4 ways:
# 1. **Decimal:0-9(base:10)**
# 2. **Binary:0&1(base:2)**
# 3. **octal:0-7(base:8)**
# 4. **Hexadecimal:0-9,A-F(base:16)**

# %%
# By default PVM takes all numbers in decimal form of base 10.
decimal=10
binary=0b10
octal=0o756
hexa=0x9874
print(decimal)
print(binary)
print(octal)
print(hexa)
# Out:
# 10
# 2
# 494
# 39028

# %% [markdown]
# # Base conversion

# %%
# we can use bin() to change any base to binary
print(bin(15))
print(bin(0o756))
print(bin(0x9874))
# Out:
# 0b1111
# 0b111101110
# 0b1001100001110100

# %%
# we can use oct() to change any base to oct
print(oct(0b111101110))
print(oct(15))
print(oct(0x9874))
# Out:
# 0o756
# 0o17
# 0o114164

# %%
# we can use hex() to change any base to hex.
print(hex(0b1001100001110100))
print(hex(39028))
print(hex(0o114164))
# Out:
# 0x9874
# 0x9874
# 0x9874

# %% [markdown]
# ## Floats
#
# Float literals can be created by adding a decimal component to a number.

# %%
floating_value=10.546
print(id(floating_value))
print(type(floating_value))
# Out:
# 1579974045616
# <class 'float'>

# %%
c=10+5j
print("The value of c is :",c)
print("The id of c is :",id(c))
print("The type value of c is :",type(c))
# Out:
# The value of c is : (10+5j)
# The id of c is : 1579985501296
# The type value of c is : <class 'complex'>

# %%
a=True
b=False
print(" The type 0f a is:",type(a))
print(" The type 0f b is:",type(b))
print(' The id of a is:',id(a))
print(' The id of b is:',id(b))
# Out:
#  The type 0f a is: <class 'bool'>
#  The type 0f b is: <class 'bool'>
#  The id of a is: 140717970405856
#  The id of b is: 140717970405888

# %% [markdown]
# ### Strings
#
# String literals can be defined with any of single quotes ('), double quotes (") or triple quotes (''' or """). All give the same result with two important differences.
#
# If you quote with single quotes, you do not have to escape double quotes and vice-versa.
# If you quote with triple quotes, your string can span multiple lines.

# %%
"Sai Vardhan"
'sai Babburi'
"There's something to write and say"
'Shakespeare said "Please be patience and try to code"'
"warriorsfan123!"
"5.00$"
""
''
" " #Not an empty string there is space in between.
"""

"""
# Out:
# '\n\n'

# %%
first_name='Sai vardhan'
print('My first name is:',first_name)
print('My type value of first name is:',type(first_name))
print('My id first name is:',id(first_name))
# Out:
# My first name is: Sai vardhan
# My type value of first name is: <class 'str'>
# My id first name is: 1579984042672

# %% [markdown]
# ### None Type
#
# Represents the absence of a value.

# %%
h=None
print(h)
print(type(h))
print(id(h))
# Out:
# None
# <class 'NoneType'>
# 140717970487424

# %% [markdown]
# ### Block Structure and Whitespace
#
# The code that is executed when a specific condition is met is defined in a "block."
#
# In Python, the block structure is signalled by changes in indentation. Each line of code in a certain block level must be indented equally and indented more than the surrounding scope. The standard (defined in PEP-8) is to use 4 spaces for each level of block indentation. Statements preceding blocks generally end with a colon (:).
#
# Because there are no semi-colons or other end-of-line indicators in Python, breaking lines of code requires either a continuation character (\ as the last char) or for the break to occur inside an unfinished structure (such as open parentheses).

# %%
total = 10 + 56 + 23+ \
      100 + 10
print(total)
# Out:
# 199

# %% [markdown]
# In Python, primitive data types and container data types are fundamental concepts that help you store and manage data in different ways.
#
# Since we have already seen Primitive data types in last lecture, let's see some common Container data types.

# %% [markdown]
# ### 8. Programming errors

# %% [markdown]
# **1. Syntax Error**
#
# Syntax errors occur if the code is written in a way that it does not comply with the rules / standards / laws of the language (python in this case).

# %%
9value = 2
# Out:
#   Cell In[84], line 1
#     9value = 2
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **2. Run-time Error**
#
# Run-time errors occur when a code is syntactically correct, but there are other issues with the code such as:
#
# 1. Misspelled or incorrectly capitalized variable and function names
# 2. Attempts to perform operations (such as math operations) on data of the wrong type (ex. attempting to subtract two variables that hold string values)
# 3. Dividing by zero
# 4. Attempts to use a type conversion function such as int on a value that can’t be converted to an int

# %%
multiplication_result = x * 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 multiplication_result = x * 4
#
# NameError: name 'x' is not defined

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero
