# %%
#Write a program to create a new string made of an input string’s first, middle, and last character.
a='sai vardhan'
b=a[0]+a[len(a)//2]+a[len(a)-1]
print(b)
# Out:
# san

# %%
#Write a program to create a new string made of the middle three characters of an input string
a='sai vardhan'
b=a[len(a)//2-1]+a[len(a)//2]+a[len(a)//2+1]
print(b)
# Out:
# var

# %%
def get_middle_characters(a='sai vardhan'):
    middle=int(len(a)/2)
    b=a[middle-1:middle+2]
    return b
s=get_middle_characters()
print(s)
# Out:
# var

# %%
def get_middle_characters(a='sai vardhan'):
    middle=int(len(a)/2)
    b=a[middle-1:middle+2]
    print(b)
get_middle_characters()
# Out:
# var

# %%
def get_middle_characters(a):
    middle=int(len(a)/2)
    b=a[middle-1:middle+2]
    print(b)
get_middle_characters()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3     b=a[middle-1:middle+2]
#       4     print(b)
# ----> 5 get_middle_characters()
#
# TypeError: get_middle_characters() missing 1 required positional argument: 'a'

# %%
def get_middle_characters(a):
    middle=int(len(a)/2)
    b=a[middle-1:middle+2]
    return b
print(get_middle_characters('saivardhan'))
# Out:
# ard

# %%
#Given two strings, s1 and s2. Write a program to create a new string s3 by appending s2 in the middle of s1
def append_middle(a,b):
    x=''
    mi=int(len(a)/2)
    x+=a[:mi]
    x+=b
    x+=a[mi:]
    return x
s=append_middle('Siva sai','vardhan')
print("The new string is:",s)
# Out:
# The new string is: Sivavardhan sai

# %%
def fml_characters(*s):
    new_string=''
    for i in s:
        s1=str(i)
        new_string+=s1[0]+s1[len(s1)//2]+s1[len(s1)-1]
    return new_string
a=fml_characters('India','Japan')
print(a)
# Out:
# IdaJpn

# %%
def fml_characters(*s):
    new_string=''
    for i in s:
        new_string+=i[0]+i[len(i)//2]+i[len(i)-1]
    return new_string
a=fml_characters('India','Japan')
print(a)
# Out:
# IdaJpn

# %%
#Given string contains a combination of the lower and upper case letters. 
#Write a program to arrange the characters of a string so that all lowercase letters should come first.
a='PyNaTive'
b=''
c=''
for i in a:
    if i.islower():
        b+=i
    else:
        c+=i
n=b+c
print(n)
# Out:
# yaivePNT

# %%
a='PyNaTiVe'
print('The String is:',a)
lower=[]
upper=[]
for i in a:
    if i.islower():
        lower.append(i)
    else:
        upper.append(i)
string=''.join(lower+upper)
print(string)
# Out:
# The String is: PyNaTiVe
# yaiePNTV

# %%
#Exercise 5: Count all letters, digits, and special symbols from a given string
str1 = "P@#yn26at^&i5ve"
def count(s1):
    char=0
    nums=0
    symbols=0
    for i in str1:
        if i.isalpha():
            char+=1
        elif i.isnumeric():
            nums+=1
        else:
            symbols+=1
    return char,nums,symbols
a,b,c=count(str1)
print(a,b,c)
# Out:
# 8 3 4

# %%
s1='abc'
s2='xyz'
s1_length=len(s1)
s2_length=len(s2)
length =s1_length if s1_length > s2_length else s2_length
result=''
s2=s2[::-1]
for i in range(length):
    if i<s1_length:
        result+=s1[i]
    if i<s2_length:
        result+=s2[i]
print(result)
# Out:
# azbycx

# %%
s1='abc'
s2='xyzdef'
s1_length=len(s1)
s2_length=len(s2)
length =s1_length if s1_length > s2_length else s2_length
result=''
s2=s2[::-1]
for i in range(length):
    if i<s1_length:
        result+=s1[i]
    if i<s2_length:
        result+=s2[i]
print(result)
# Out:
# afbecdzyx

# %%
#Write a program to check if two strings are balanced. 
#For example, strings s1 and s2 are balanced if all the characters in the s1 are present in s2. The character’s position doesn’t matter.
def balanced(s1,s2):
    flag=True
    for i in s1:
        if i in s2:
            continue
        else:
            flag=False
    return flag
s=balanced('yn','Pynative')
print(s)
# Out:
# True

# %%
s=balanced('ynf','pynative')
s
# Out:
# False

# %%
#Write a program to find all occurrences of “USA” in a given string ignoring the case.
str1 = "Welcome to USA. usa awesome, isn't it?"
str2='usa'
lower_case=str1.lower()
count=lower_case.count('usa')
print(count)
# Out:
# 2

# %%
#Given a string s1, write a program to return the sum and average of the digits that appear in the string, ignoring all other characters.
str1 = "PYnative29@#8496"
sum=0
n=0
for i in str1:
    if i.isnumeric():
        sum+=int(i)
        n+=1
avg=sum/n
print(avg)
# Out:
# 6.333333333333333

# %%
str1 = "Apple"
c=dict()
for char in str1:
    count=0
    count=str1.count(char)
    c[char]=count
print(c)
# Out:
# {'A': 1, 'p': 2, 'l': 1, 'e': 1}

# %%
a='pynative'
a[::-1]
# Out:
# 'evitanyp'

# %%
print(''.join(reversed(a)))
# Out:
# evitanyp

# %%
str1 = 'Emma-is-a-data-scientist'
str2=str1.split("-")
print(str2)
str3=" ".join(str2)
print(str3)
# Out:
# ['Emma', 'is', 'a', 'data', 'scientist']
# Emma is a data scientist

# %%
import string
string.punctuation
str1 = "/*Jon is @developer & musician"
res=str1.translate(str1.maketrans("","",string.punctuation))
res
# Out:
# 'Jon is developer  musician'
