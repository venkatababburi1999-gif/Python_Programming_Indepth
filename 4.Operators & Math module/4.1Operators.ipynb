# %% [markdown]
# ### 7. Expressions in Python
#
# An expression is a combination of operators and operands that is interpreted to produce some other value.
#
# In any programming language, an expression is evaluated as per the precedence and associativity of its operators.
#
# So that if there is more than one operator in an expression, their precedence decides which operation will be performed first.
#
# If an expression contains two or more operators with the same precedence then Operator Associativity is used to determine. It can either be Left to Right or from Right to Left.
#
# Let's discuss different types of expressions in Python.

# %% [markdown]
# ## Arithmetic Operators:
# - Addition(+): a + b
# - Subtraction(-): a - b
# - Multiplication(*): a * b
# - Division(/): a / b
# - Modulus(%): a % b
# - Floor division(//): a // b
# - Exponentiation(**): a ** b
# ![image.png](attachment:4e85f9b1-c454-4d95-8e4f-5e25a15c5b2a.png)

# %%
a=10
b=3
print("The addition(+) of a,b is a+b:",a+b)
print("The subtraction(-) of a,b is a-b:",a-b)
print("The multiplcationtion(*) of a,b is a*b:",a*b)
print("The division(/) of a,b is a/b:",a/b)
print("The Modulus(%) of a,b is a%b:",a%b)
print("The exponentitation(**) of a,b is a**b:",a**b)
print("The floor division(//) of a,b is a//b:",a//b)
# Out:
# The addition(+) of a,b is a+b: 13
# The subtraction(-) of a,b is a-b: 7
# The multiplcationtion(*) of a,b is a*b: 30
# The division(/) of a,b is a/b: 3.3333333333333335
# The Modulus(%) of a,b is a%b: 1
# The exponentitation(**) of a,b is a**b: 1000
# The floor division(//) of a,b is a//b: 3

# %% [markdown]
# ## Comparison Operators
# In programming we compare values, we use comparison operators to compare two values. We check if a value is greater or less or equal to other value. The following table shows Python comparison operators which was taken from
# ![image.png](attachment:d6452ce8-a6b7-46ca-8dcb-4b3597ac4df1.png)

# %%
a=10
b=3
print("\nComparison Operators")
print("a==b",a==b)
print("a>b", a>b)
print("a<b", a<b)
print("a>=b",a>=b)
print("a<=b",a<=b)
print("a!=b",a!=b)
# Out:
# Comparison Operators
# a==b False
# a>b True
# a<b False
# a>=b True
# a<=b False
# a!=b True

# %%
print(len('Mango')==len('Apple'))
print(len('mango') == len('avocado'))  # False
print(len('mango') != len('avocado'))  # True
print(len('mango') < len('avocado'))   # True
print(len('milk') != len('meat'))      # False
print(len('milk') == len('meat'))      # True
print(len('tomato') == len('potato'))  # True
print(len('python') > len('dragon'))   # False
# Out:
# True
# False
# True
# True
# False
# True
# True
# False

# %% [markdown]
# ![image.png](attachment:772d2215-4991-4008-b5cd-363b8cb80032.png)

# %%
print((3<2) and (3>2))
print((3>2) and (5<6))
print((3<2) or (3>2))
print((3<2) or (5>2))
print(not((3<2) and (3>2)))
# Out:
# False
# True
# True
# True
# True

# %% [markdown]
# # Assignment Operators
# Assignment operators are used to assign values to variables. Let us take = as an example. Equal sign in mathematics shows that two values are equal, however in Python it means we are storing a value in a certain variable and we call it assignment or a assigning value to a variable. The table below shows the different types of python assignment operators

# %% [markdown]
# ![image.png](attachment:a6880f81-875d-4398-b1d4-0eb76190d2f6.png)

# %%
print("\nAssignment Operators:")
c=5
print("The intital value of c is :",c)
c+=2
print("The value after c+=2 is :",c)
c*=3
print("The value after c*=3 is :",c)
c-=4
print("The value after c-=4 is :",c)
c/=2
print("The value after c/=2 is :",c)
c**=2
print("The value after c**=2 is :",c)
c//=2
print("The value after c//=2 is :",c)
# Out:
# Assignment Operators:
# The intital value of c is : 5
# The value after c+=2 is : 7
# The value after c*=3 is : 21
# The value after c-=4 is : 17
# The value after c/=2 is : 8.5
# The value after c**=2 is : 72.25
# The value after c//=2 is : 36.0

# %% [markdown]
# ![image.png](attachment:b16c1085-2809-40e4-9874-c5d2504ebba3.png)

# %% [markdown]
# ![image.png](attachment:4b53b6a0-a32c-4631-a938-4acc60b6f12e.png)
