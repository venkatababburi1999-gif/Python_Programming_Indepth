# %% [markdown]
# ![image.png](attachment:08c6e80f-ac23-4420-8204-4f4265a5c5fe.png)

# %%
a={'apple','banana','mango','orange'}
print(a,type(a))
a.add('Grapes')
print(a,type(a))
a.remove('Grapes')
print(a,type(a))
a.discard('mango')
print(a,type(a))
a.remove('grapes')
print(a,type(a))
# Out:
# {'mango', 'orange', 'apple', 'banana'} <class 'set'>
# {'orange', 'apple', 'Grapes', 'mango', 'banana'} <class 'set'>
# {'orange', 'apple', 'mango', 'banana'} <class 'set'>
# {'orange', 'apple', 'banana'} <class 'set'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 9
#       7 a.discard('mango')
#       8 print(a,type(a))
# ----> 9 a.remove('grapes')
#      10 print(a,type(a))
#
# KeyError: 'grapes'

# %%
#Find the union of set1 and set2. Write a Python program to return a new set with unique items from both sets by removing duplicates.
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
a=set1|set2
print(a)
# Out:
# {70, 40, 10, 50, 20, 60, 30}

# %%
#find the intersection of set1 and set2. Write a code to return a new set containing only the elements that are common to both set1 and set2
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
b=set1&set2
print(b)
# Out:
# {40, 50, 30}

# %%
#Find the difference (set1 - set2). Write a code to returns a new set containing elements that are present in set1 but not in set2.
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
b=set1-set2
print(b)
# Out:
# {10, 20}

# %%
#Symmetric Difference
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
c=set1.symmetric_difference(set2)
print(c)
# Out:
# {20, 70, 10, 60}

# %%
sample_set = {"Yellow", "Orange", "Black"}
sample_list = ["Blue", "Green", "Red"]

sample_set.update(sample_list)
print(sample_set)
# Out:
# {'Orange', 'Yellow', 'Black', 'Green', 'Blue', 'Red'}

# %%
set1 = {10, 20, 30}
set2 = {20, 40, 50}
set1.difference_update(set2)
print(set1)
# Out:
# {10, 30}

# %%
set1 = {10, 20, 30, 40, 50}
set1.difference_update({10,20,30})
print(set1)
# Out:
# {50, 40}

# %%
subset_set = {10, 20}
main_set = {10, 20, 30, 40}
print(subset_set.issubset(main_set))
# Out:
# True

# %%
subset_set = {10, 20}
main_set = {10, 20, 30, 40}
print(main_set.issuperset(main_set))
# Out:
# True

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {60, 70, 80, 90, 10}
if set1.isdisjoint(set2):
    print('No common elements ')
else:
    print('Common Elements')
# Out:
# Common Elements

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {20, 70, 10, 60}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set1.intersection_update(set2)
print(set1)
# Out:
# {40, 50, 30}

# %%
list1 = [10, 20, 30, 40]
list2 = [30, 40, 50, 60]

set_list1 = set(list1)
set_list2 = set(list2)

common_elements = set_list1.intersection(set_list2)
print(f"List 1: {list1}")
print(f"List 2: {list2}")
print(f"Common elements using sets: {common_elements}")
# Out:
# List 1: [10, 20, 30, 40]
# List 2: [30, 40, 50, 60]
# Common elements using sets: {40, 30}

# %%
my_list = [10, 20, 30]
readonly_set=frozenset(my_list)
print(readonly_set)
# Out:
# frozenset({10, 20, 30})

# %%
sentence = "dog is a simple animal dogs is selfless animal"
s=sentence.split()
s=set(s)
print(len(s))
# Out:
# 7
